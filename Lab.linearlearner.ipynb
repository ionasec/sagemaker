# %%
import numpy as np
import boto3
import sagemaker
import io
import sagemaker.amazon.common as smac
import os
import pandas as pd

# Read csv from s3.
# Download from your S3 bucket the bike share data CSV file based on the publically available bike share data from the ML repository curated by the University of California, Irvine
from io import StringIO
s3 = boto3.resource('s3')
bucket = 'raz-eu-central-1-tutorial' # place the day.csv file in a bucket in your account
object_key = 'sagemaker/machine-learning-exam/day.csv'

# Load the data into a pandas dataframe 
csv_obj = s3.Object(bucket, object_key)
csv_string = csv_obj.get()['Body'].read().decode('utf-8')

dataset = pd.read_csv(StringIO(csv_string))
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Convert categorical date field
dataset['dteday'] = dataset['dteday'].str.replace("-","")
dataset.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  20110101       1   0     1        0        6           0
# 1        2  20110102       1   0     1        0        0           0
# 2        3  20110103       1   0     1        0        1           1
# 3        4  20110104       1   0     1        0        2           1
# 4        5  20110105       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Randomize the data and split it between train and test datasets on a 70% 30% split respectively
train_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset))])
print(train_data.shape, test_data.shape)
# Out:
# (511, 16) (220, 16)

# %%
# Get the features and labels.
feature_dataset = train_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed' ]]
features = np.array(feature_dataset.values).astype('float32')

label_dataset= train_data[['cnt']]
labels = np.array(label_dataset.values).astype('float32')
labels_vec = np.squeeze(np.asarray(labels))

# %%
# Setup protoBuf
buffer = io.BytesIO()
smac.write_numpy_to_dense_tensor(buffer, features, labels_vec)
buffer.seek(0)

prefix = 'realestate'
key = 'linearregression'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buffer)
s3_training_data_location = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('training dataset will be uploaded to: {}'.format(s3_training_data_location))
# Out:
# training dataset will be uploaded to: s3://raz-eu-central-1-tutorial/realestate/train/linearregression

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('model artifacts will be uploaded to: {}'.format(output_location))
# Out:
# model artifacts will be uploaded to: s3://raz-eu-central-1-tutorial/realestate/output

# %%
# Get the Linear Learner container instance
from sagemaker.amazon.amazon_estimator import get_image_uri
linear_container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
# Train the model
from sagemaker import get_execution_role

role = get_execution_role()

sagemaker_session = sagemaker.Session()

# Provide the container, role, instance type and model output location
linear = sagemaker.estimator.Estimator(linear_container,
                                       role=role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sagemaker_session)

# Provide the number of features identified during data preparation
# Provide the predictor_type 

linear.set_hyperparameters(feature_dim=13,
                           mini_batch_size=4,
                           predictor_type='regressor')

# Train the model using the previously prepared test data and validate the 
# data by providing the validation data.

linear.fit({'train': s3_training_data_location})
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-11-13 18:04:38 Starting - Starting the training job...
# 2020-11-13 18:04:40 Starting - Launching requested ML instances......
# 2020-11-13 18:05:47 Starting - Preparing the instances for training.........
# 2020-11-13 18:07:12 Downloading - Downloading input data...
# 2020-11-13 18:07:55 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/13/2020 18:08:19 INFO 139679959119680] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/13/2020 18:08:19 INFO 139679959119680] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'4', u'predictor_type': u'regressor'}
# [11/13/2020 18:08:19 INFO 139679959119680] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'4', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [11/13/2020 18:08:19 WARNING 139679959119680] Loggers have already been setup.
# Process 1 is a worker.
# [11/13/2020 18:08:19 INFO 139679959119680] Using default worker.
# [11/13/2020 18:08:19 INFO 139679959119680] Checkpoint loading and saving are disabled.
# [2020-11-13 18:08:19.520] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes":
, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1605290935.532339, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1605290933.51557}
#
# [11/13/2020 18:08:55 INFO 139679959119680] #throughput_metric: host=algo-1, train throughput=253.360754859 records/second
# [11/13/2020 18:08:55 WARNING 139679959119680] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/13/2020 18:08:55 WARNING 139679959119680] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-11-13 18:08:55.533] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 0, "num_examples": 1, "num_bytes": 384}
# [2020-11-13 18:08:55.685] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 149, "num_examples": 128, "num_bytes": 49056}
# [11/13/2020 18:08:55 INFO 139679959119680] #train_score (algo-1) : ('mse_objective', 803523.4458476028)
# [11/13/2020 18:08:55 INFO 139679959119680] #train_score (algo-1) : ('mse', 803523.4458476028)
# [11/13/2020 18:08:55 INFO 139679959119680] #train_score (algo-1) : ('absolute_loss', 667.059686888454)
# [11/13/2020 18:08:55 INFO 139679959119680] #quality_metric: host=algo-1, train mse_objective <loss>=803523.445848
# [11/13/2020 18:08:55 INFO 139679959119680] #quality_metric: host=algo-1, train mse <loss>=803523.445848
# [11/13/2020 18:08:55 INFO 139679959119680] #quality_metric: host=algo-1, train absolute_loss <loss>=667.059686888
# [11/13/2020 18:08:55 INFO 139679959119680] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [11/13/2020 18:08:55 INFO 139679959119680] Saved checkpoint to "/tmp/tmpjyNgci/mx-mod-0000.params"
# [11/13/2020 18:08:55 INFO 139679959119680] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 36397.624015808105, "sum": 36397.624015808105, "min": 36397.624015808105}, "finalize.time": {"count": 1, "max": 153.37491035461426, "sum": 153.37491035461426, "min": 153.37491035461426}, "initialize.time": {"count": 1, "max": 877.0120143890381, "sum": 877.0120143890381, "min": 877.0120143890381}, "check_early_stopping.time": {"count": 15, "max": 1.161813735961914, "sum": 15.11693000793457, "min": 0.9171962738037109}, "setuptime": {"count": 1, "max": 24.97696876525879, "sum": 24.97696876525879, "min": 24.97696876525879}, "update.time": {"count": 15, "max": 2821.7620849609375, "sum": 35108.33144187927, "min": 2014.5230293273926}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1605290935.69106, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1605290899.50276}
#
#
# 2020-11-13 18:09:04 Uploading - Uploading generated training model
# 2020-11-13 18:09:04 Completed - Training job completed
# Training seconds: 112
# Billable seconds: 112

# %%
# Deploy the model
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.c4.xlarge',
                                 endpoint_name='bikeshare-sagemaker-regression-v2')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Using already existing model: linear-learner-2020-11-13-18-04-38-473
# --------

# %%
# Get prediction using the test data
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

test_feature_dataset = test_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']]

test_actuals = np.array(test_data['cnt'].astype('float32'))
test_features = np.array(test_feature_dataset.values).astype('float32')

predictions = []
actuals = []
for tf, actual in zip(test_features, test_actuals):
    prediction = linear_predictor.predict(tf)
    predictions.append(prediction['predictions'][0]['score'])
    actuals.append(actual)
    print('prediction: ', prediction['predictions'][0]['score'], '\t\tactual: ', str(actual))
# Out:
# prediction:  1434.75 		actual:  801.0
# prediction:  4526.875 		actual:  5217.0
# prediction:  6714.25 		actual:  7767.0
# prediction:  5827.0 		actual:  6852.0
# prediction:  2056.5 		actual:  2209.0
# prediction:  6624.25 		actual:  6290.0
# prediction:  5409.125 		actual:  4792.0
# prediction:  1713.625 		actual:  1865.0
# prediction:  5868.75 		actual:  5668.0
# prediction:  3618.875 		actual:  4492.0
# prediction:  5096.125 		actual:  4367.0
# prediction:  2249.625 		actual:  2402.0
# prediction:  6108.0 		actual:  3846.0
# prediction:  3904.0 		actual:  4788.0
# prediction:  3168.875 		actual:  3190.0
# prediction:  3984.375 		actual:  3005.0
# prediction:  7536.75 		actual:  7286.0
# prediction:  2331.125 		actual:  2132.0
# prediction:  6911.0 		actual:  5464.0
# prediction:  4981.0 		actual:  4985.0
# prediction:  5431.25 		actual:  6304.0
# prediction:  5541.0 		actual:  5532.0
# prediction:  6997.125 		actual:  8009.0
# prediction:  2104.75 		actual:  2999.0
# prediction:  4583.625 		actual:  4338.0
# prediction:  5173.25 		actual:  3510.0
# prediction:  7262.625 		actual:  6883.0
# prediction:  3455.625 		actual:  4760.0
# prediction:  3793.25 		actual:  4362.0
# prediction:  2267.875 		actual:  2895.0
# prediction:  6504.5 		actual:  6770.0
# prediction:  4064.5 		actual:  4109.0
# prediction:  2974.625 		actual:  3351.0
# prediction:  6432.75 		actual:  7333.0
# prediction:  7053.0 		actual:  7865.0
# prediction:  5674.625 		actual:  6073.0
# prediction:  4061.875 		actual:  3544.0
# prediction:  5186.0 		actual:  5099.0
# prediction:  4389.875 		actual:  4294.0
# prediction:  4886.75 		actual:  5204.0
# prediction:  5567.375 		actual:  4258.0
# prediction:  6231.0 		actual:  6536.0
# prediction:  5740.875 		actual:  6043.0
# prediction:  6673.625 		actual:  6598.0
# prediction:  1483.375 		actual:  1708.0
# prediction:  3830.0 		actual:  3292.0
# prediction:  4413.375 		actual:  6041.0
# prediction:  4147.125 		actual:  3194.0
# prediction:  5515.0 		actual:  5611.0
# prediction:  5559.625 		actual:  4905.0
# prediction:  3135.0 		actual:  3577.0
# prediction:  3835.625 		actual:  4660.0
# prediction:  1433.375 		actual:  1543.0
# prediction:  5317.625 		actual:  4661.0
# prediction:  5017.625 		actual:  5382.0
# prediction:  7439.875 		actual:  6830.0
# prediction:  5250.875 		actual:  5202.0
# prediction:  3577.0 		actual:  3659.0
# prediction:  3520.625 		actual:  2177.0
# prediction:  4495.375 		actual:  5046.0
# prediction:  4060.75 		actual:  3243.0
# prediction:  4204.875 		actual:  4075.0
# prediction:  4852.5 		actual:  5459.0
# prediction:  5649.5 		actual:  4332.0
# prediction:  3641.375 		actual:  3767.0
# prediction:  1760.375 		actual:  2192.0
# prediction:  3695.375 		actual:  3820.0
# prediction:  1482.125 		actual:  1650.0
# prediction:  6744.125 		actual:  6734.0
# prediction:  3552.375 		actual:  3163.0
# prediction:  4757.5 		actual:  4375.0
# prediction:  2882.5 		actual:  3249.0
# prediction:  5071.75 		actual:  6273.0
# prediction:  6370.875 		actual:  7591.0
# prediction:  3138.25 		actual:  3811.0
# prediction:  2452.0 		actual:  2133.0
# prediction:  3975.375 		actual:  3389.0
# prediction:  1592.25 		actual:  1550.0
# prediction:  5188.0 		actual:  5409.0
# prediction:  3906.25 		actual:  4035.0
# prediction:  7037.25 		actual:  6917.0
# prediction:  1586.75 		actual:  795.0
# prediction:  5250.0 		actual:  6269.0
# prediction:  4592.5 		actual:  1096.0
# prediction:  3178.25 		actual:  3331.0
# prediction:  4089.25 		actual:  4649.0
# prediction:  3045.125 		actual:  2475.0
# prediction:  7298.0 		actual:  6966.0
# prediction:  3010.625 		actual:  3744.0
# prediction:  5445.75 		actual:  4845.0
# prediction:  5090.375 		actual:  5538.0
# prediction:  4083.875 		actual:  2792.0
# prediction:  6574.0 		actual:  7665.0
# prediction:  4249.875 		actual:  4727.0
# prediction:  6908.25 		actual:  7403.0
# prediction:  1445.625 		actual:  1944.0
# prediction:  2132.375 		actual:  705.0
# prediction:  5927.625 		actual:  7852.0
# prediction:  4204.0 		actual:  3487.0
# prediction:  4161.5 		actual:  3777.0
# prediction:  2330.625 		actual:  2169.0
# prediction:  1327.25 		actual:  754.0
# prediction:  6407.875 		actual:  7570.0
# prediction:  2096.375 		actual:  1536.0
# prediction:  5688.75 		actual:  5169.0
# prediction:  2961.0 		actual:  1951.0
# prediction:  6713.875 		actual:  7736.0
# prediction:  1619.25 		actual:  1693.0
# prediction:  3021.0 		actual:  1341.0
# prediction:  3786.0 		actual:  4195.0
# prediction:  1185.25 		actual:  1360.0
# prediction:  5660.75 		actual:  5740.0
# prediction:  3065.875 		actual:  3623.0
# prediction:  5323.25 		actual:  4991.0
# prediction:  4160.5 		actual:  4456.0
# prediction:  6218.625 		actual:  6591.0
# prediction:  4486.625 		actual:  5423.0
# prediction:  3633.75 		actual:  4274.0
# prediction:  6491.25 		actual:  7424.0
# prediction:  4511.0 		actual:  5511.0
# prediction:  4465.625 		actual:  4339.0
# prediction:  3784.5 		actual:  6043.0
# prediction:  4151.0 		actual:  4187.0
# prediction:  6517.875 		actual:  5786.0
# prediction:  5120.125 		actual:  4086.0
# prediction:  3403.875 		actual:  3649.0
# prediction:  1995.125 		actual:  1815.0
# prediction:  6298.875 		actual:  7384.0
# prediction:  4185.625 		actual:  3830.0
# prediction:  851.0 		actual:  1605.0
# prediction:  6572.75 		actual:  7702.0
# prediction:  6620.75 		actual:  8395.0
# prediction:  7459.125 		actual:  8173.0
# prediction:  4659.25 		actual:  4826.0
# prediction:  7215.0 		actual:  7693.0
# prediction:  4961.5 		actual:  5895.0
# prediction:  6223.625 		actual:  7444.0
# prediction:  7583.125 		actual:  6685.0
# prediction:  5428.375 		actual:  4592.0
# prediction:  7304.25 		actual:  7592.0
# prediction:  5482.75 		actual:  5585.0
# prediction:  6692.625 		actual:  7415.0
# prediction:  2271.5 		actual:  2077.0
# prediction:  1423.25 		actual:  1510.0
# prediction:  2509.875 		actual:  3126.0
# prediction:  3099.375 		actual:  2808.0
# prediction:  2115.875 		actual:  2252.0
# prediction:  5210.125 		actual:  4629.0
# prediction:  3662.75 		actual:  3115.0
# prediction:  2785.25 		actual:  2729.0
# prediction:  4293.25 		actual:  4687.0
# prediction:  4388.875 		actual:  3907.0
# prediction:  5366.25 		actual:  6370.0
# prediction:  3630.0 		actual:  3669.0
# prediction:  5168.0 		actual:  5728.0
# prediction:  5017.5 		actual:  3372.0
# prediction:  3316.125 		actual:  2703.0
# prediction:  5767.25 		actual:  5557.0
# prediction:  2896.375 		actual:  4123.0
# prediction:  4338.25 		actual:  4308.0
# prediction:  4076.875 		actual:  3944.0
# prediction:  988.75 		actual:  1685.0
# prediction:  5086.25 		actual:  5558.0
# prediction:  5476.0 		actual:  5847.0
# prediction:  4495.125 		actual:  5035.0
# prediction:  3886.125 		actual:  4400.0
# prediction:  4662.125 		actual:  5342.0
# prediction:  3228.25 		actual:  4046.0
# prediction:  4475.5 		actual:  4844.0
# prediction:  4549.625 		actual:  4570.0
# prediction:  5529.375 		actual:  4602.0
# prediction:  4424.75 		actual:  4630.0
# prediction:  3043.875 		actual:  2424.0
# prediction:  6765.875 		actual:  7572.0
# prediction:  5544.5 		actual:  6233.0
# prediction:  5479.0 		actual:  4972.0
# prediction:  5643.75 		actual:  4656.0
# prediction:  3107.5 		actual:  1027.0
# prediction:  858.375 		actual:  959.0
# prediction:  4803.125 		actual:  4758.0
# prediction:  4360.625 		actual:  4120.0
# prediction:  3884.875 		actual:  3267.0
# prediction:  5190.375 		actual:  4586.0
# prediction:  4083.25 		actual:  4748.0
# prediction:  8185.75 		actual:  6207.0
# prediction:  6440.125 		actual:  7639.0
# prediction:  3003.625 		actual:  2566.0
# prediction:  3034.625 		actual:  4105.0
# prediction:  4418.75 		actual:  4576.0
# prediction:  2739.125 		actual:  3053.0
# prediction:  5636.0 		actual:  5698.0
# prediction:  3981.875 		actual:  4073.0
# prediction:  4172.0 		actual:  4304.0
# prediction:  5335.25 		actual:  5986.0
# prediction:  3769.375 		actual:  3894.0
# prediction:  4833.25 		actual:  4785.0
# prediction:  1990.625 		actual:  1589.0
# prediction:  3577.25 		actual:  2935.0
# prediction:  4899.625 		actual:  4459.0
# prediction:  5323.375 		actual:  4579.0
# prediction:  2897.875 		actual:  2368.0
# prediction:  3496.5 		actual:  2802.0
# prediction:  2985.125 		actual:  3747.0
# prediction:  4699.625 		actual:  3574.0
# prediction:  2470.75 		actual:  2594.0
# prediction:  7165.75 		actual:  7040.0
# prediction:  3106.75 		actual:  2236.0
# prediction:  5238.375 		actual:  3784.0
# prediction:  3863.5 		actual:  2732.0
# prediction:  5576.875 		actual:  5255.0
# prediction:  5416.125 		actual:  4342.0
# prediction:  7554.875 		actual:  5531.0
# prediction:  3706.875 		actual:  4067.0
# prediction:  1295.625 		actual:  1891.0
# prediction:  3907.625 		actual:  3376.0
# prediction:  5967.875 		actual:  6978.0
# prediction:  7720.75 		actual:  6660.0
# prediction:  4923.625 		actual:  5115.0
# prediction:  2335.375 		actual:  2162.0
# prediction:  5758.0 		actual:  5875.0

# %%
# Get accuracy using Cosine Similarity method 
from numpy import dot
from numpy.linalg import norm
tolerance = 1e-10
accuracy = (dot(actuals, predictions)/(norm(actuals)*norm(predictions))) * 100
print('accuracy: ', accuracy)
# Out:
# accuracy:  98.6166473968964

# %%
# delete the endpoint
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
