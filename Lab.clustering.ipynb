# %%
import os
import boto3
import io
import sagemaker

# %matplotlib inline 

import pandas as pd
import numpy as np
#import mxnet as mx
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
matplotlib.style.use('ggplot')
import pickle, gzip, urllib, json
import csv
from sagemaker import get_execution_role
role = get_execution_role()
s3 = boto3.resource('s3')
bucket_name = 'raz-eu-central-1-tutorial' # place the USCensus1990.data.csv file in a bucket in your account
object_key = 'Absenteeism_at_work.csv'

# %%
# Load our absenteeism data
s3_client = boto3.client('s3')
response = s3_client.get_object(Bucket=bucket_name, Key=object_key)
response_body = response["Body"].read()
absence = pd.read_csv(io.BytesIO(response_body), header=0, delimiter=",", low_memory=False)

# %%
absence.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# 0                 239.554  ...                     0          1    2
# 1                 239.554  ...                     1          1    1
# 2                 239.554  ...                     0          1    0
# 3                 239.554  ...                     0          1    2
# 4                 239.554  ...                     0          1    2
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    1      90     172               30
# 1               1              0    0      98     178               31
# 2               1              0    0      89     170               31
# 3               1              1    0      68     168               24
# 4               1              0    1      90     172               30
#
#    Absenteeism time in hours
# 0                          4
# 1                          0
# 2                          2
# 3                          4
# 4                          2
#
# [5 rows x 21 columns]

# %%
# Drop the ID column
absence = absence.drop(['ID'], axis=1)

# %%
absence.shape
# Out:
# (740, 20)

# %%
# Drop any missing value observations
absence.dropna(inplace=True)
absence.shape
# Out:
# (740, 20)

# %%
# Set the 'Reason for absence' as the index 
# and the rest of the numerical features become the attributes of each unique absence
absence.index=absence['Reason for absence']
absence.head()
# Out:
#                     Reason for absence  Month of absence  Day of the week  \
# Reason for absence
# 26                                  26                 7                3
# 0                                    0                 7                3
# 23                                  23                 7                4
# 7                                    7                 7                5
# 23                                  23                 7                5
#
#                     Seasons  Transportation expense  \
# Reason for absence
# 26                        1                     289
# 0                         1                     118
# 23                        1                     179
# 7                         1                     279
# 23                        1                     289
#
#                     Distance from Residence to Work  Service time  Age  \
# Reason for absence
# 26                                               36            13   33
# 0                                                13            18   50
# 23                                               51            18   38
# 7                                                 5            14   39
# 23                                               36            13   33
#
#                     Work load Average/day   Hit target  Disciplinary failure  \
# Reason for absence
# 26                                 239.554          97                     0
# 0                                  239.554          97                     1
# 23                                 239.554          97                     0
# 7                                  239.554          97                     0
# 23                                 239.554          97                     0
#
#                     Education  Son  Social drinker  Social smoker  Pet  \
# Reason for absence
# 26                          1    2               1              0    1
# 0                           1    1               1              0    0
# 23                          1    0               1              0    0
# 7                           1    2               1              1    0
# 23                          1    2               1              0    1
#
#                     Weight  Height  Body mass index  Absenteeism time in hours
# Reason for absence
# 26                      90     172               30                          4
# 0                       98     178               31                          0
# 23                      89     170               31                          2
# 7                       68     168               24                          4
# 23                      90     172               30                          2

# %%
absence.shape
# Out:
# (740, 20)

# %%
# Visualize the data for some of our columns to see what the distribution looks like
import seaborn as sns

for a in ['Reason for absence', 'Transportation expense', 'Distance from Residence to Work']:
    ax=plt.subplots(figsize=(6,3))
    ax=sns.distplot(absence[a])
    title="Histogram of " + a
    ax.set_title(title, fontsize=12)
    plt.show()

# %%
# Standardize the scaling of the columns in order to use any distance based analytical methods 
# so that we can compare the relative distances between different feature columns
# Use minmaxscaler to transform the columns so that they also fall between 0 and 1
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
absence_scaled=pd.DataFrame(scaler.fit_transform(absence))
absence_scaled.columns=absence.columns
absence_scaled.index=absence.index

# %%
# See that all of our columns are now between 0 and 1
absence_scaled.describe()
absence_scaled.head()
# Out:
#                     Reason for absence  Month of absence  Day of the week  \
# Reason for absence
# 26                            0.928571          0.583333             0.25
# 0                             0.000000          0.583333             0.25
# 23                            0.821429          0.583333             0.50
# 7                             0.250000          0.583333             0.75
# 23                            0.821429          0.583333             0.75
#
#                     Seasons  Transportation expense  \
# Reason for absence
# 26                      0.0                0.633333
# 0                       0.0                0.000000
# 23                      0.0                0.225926
# 7                       0.0                0.596296
# 23                      0.0                0.633333
#
#                     Distance from Residence to Work  Service time       Age  \
# Reason for absence
# 26                                         0.659574      0.428571  0.193548
# 0                                          0.170213      0.607143  0.741935
# 23                                         0.978723      0.607143  0.354839
# 7                                          0.000000      0.464286  0.387097
# 23                                         0.659574      0.428571  0.193548
#
#                     Work load Average/day   Hit target  Disciplinary failure  \
# Reason for absence
# 26                                0.194471    0.842105                   0.0
# 0                                 0.194471    0.842105                   1.0
# 23                                0.194471    0.842105                   0.0
# 7                                 0.194471    0.842105                   0.0
# 23                                0.194471    0.842105                   0.0
#
#                     Education   Son  Social drinker  Social smoker    Pet  \
# Reason for absence
# 26                        0.0  0.50             1.0            0.0  0.125
# 0                         0.0  0.25             1.0            0.0  0.000
# 23                        0.0  0.00             1.0            0.0  0.000
# 7                         0.0  0.50             1.0            1.0  0.000
# 23                        0.0  0.50             1.0            0.0  0.125
#
#                       Weight    Height  Body mass index  \
# Reason for absence
# 26                  0.653846  0.272727         0.578947
# 0                   0.807692  0.454545         0.631579
# 23                  0.634615  0.212121         0.631579
# 7                   0.230769  0.151515         0.263158
# 23                  0.653846  0.272727         0.578947
#
#                     Absenteeism time in hours
# Reason for absence
# 26                                   0.033333
# 0                                    0.000000
# 23                                   0.016667
# 7                                    0.033333
# 23                                   0.016667

# %%
import io
import numpy as np
import sagemaker.amazon.common as smac

vectors = absence_scaled.values.astype('float32')

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, vectors)
buf.seek(0)


import boto3
import os

key = 'recordio-pb-data'
prefix = 'clustering'

boto3.resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket_name, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# uploaded training data location: s3://raz-eu-central-1-tutorial/clustering/train/recordio-pb-data

# %%
# Use principal component analysis (PCA) to reduce the dimensionality of our data 
from sagemaker import PCA
num_components=19

from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'pca')

sess = sagemaker.Session()

pca = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.c4.xlarge',
                                    output_path='s3://'+ bucket_name +'/absence/',
                                    sagemaker_session=sess)

pca.set_hyperparameters(feature_dim=50000,
                        num_components=num_components,
                        subtract_mean=True,
                        algorithm_mode='randomized',
                        mini_batch_size=200)

# Extract the numpy array from the DataFrame and explicitly casting to float32

pca.fit({'train': s3_train_data})


#pca_SM = PCA(role=role,
#             train_instance_count=1,
#             train_instance_type='ml.c4.xlarge',
#             output_path='s3://'+ bucket +'/absence/',
#             num_components=num_components)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-11-14 14:25:26 Starting - Starting the training job...
# 2020-11-14 14:25:28 Starting - Launching requested ML instances......
# 2020-11-14 14:26:52 Starting - Preparing the instances for training......
# 2020-11-14 14:27:37 Downloading - Downloading input data...
# 2020-11-14 14:28:16 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/14/2020 14:28:39 INFO 140431746283328] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto'}
# [11/14/2020 14:28:39 INFO 140431746283328] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'algorithm_mode': u'randomized', u'feature_dim': u'50000', u'mini_batch_size': u'200', u'subtract_mean': u'True', u'num_components': u'19'}
# [11/14/2020 14:28:39 INFO 140431746283328] Final configuration: {u'num_components': u'19', u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'True', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'randomized', u'feature_dim': u'50000', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto', u'mini_batch_size': u'200'}
# [11/14/2020 14:28:39 WARNING 140431746283328] Loggers have already been setup.
# [11/14/2020 14:28:41 INFO 140431746283328] Launching parameter server for role scheduler
# [11/14/2020 14:28:41 INFO 140431746283328] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0d384705-769f-48b1-9f2c-72cff41fde09', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/0d384705-769f-48b1-9f2c-72cff41fde09', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-14-25-26-361', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-199-2.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/364b8f9f-757e-49fd-8b90-077f6e49e684', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-14-25-26-361', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 14:28:41 INFO 140431746283328] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0d384705-769f-48b1-9f2c-72cff41fde09', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/0d384705-769f-48b1-9f2c-72cff41fde09', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.199.2', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-14-25-26-361', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-199-2.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/364b8f9f-757e-49fd-8b90-077f6e49e684', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-14-25-26-361', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 14:28:41 INFO 140431746283328] Launching parameter server for role server
# [11/14/2020 14:28:41 INFO 140431746283328] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0d384705-769f-48b1-9f2c-72cff41fde09', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/0d384705-769f-48b1-9f2c-72cff41fde09', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-14-25-26-361', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-199-2.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/364b8f9f-757e-49fd-8b90-077f6e49e684', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-14-25-26-361', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 14:28:41 INFO 140431746283328] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0d384705-769f-48b1-9f2c-72cff41fde09', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/0d384705-769f-48b1-9f2c-72cff41fde09', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.199.2', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-14-25-26-361', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-199-2.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/364b8f9f-757e-49fd-8b90-077f6e49e684', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-14-25-26-361', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 14:28:41 INFO 140431746283328] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/0d384705-769f-48b1-9f2c-72cff41fde09', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/0d384705-769f-48b1-9f2c-72cff41fde09', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.199.2', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-14-25-26-361', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-199-2.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/364b8f9f-757e-49fd-8b90-077f6e49e684', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-14-25-26-361', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 61 is a shell:scheduler.
# Process 70 is a shell:server.
# Process 1 is a worker.
# [11/14/2020 14:28:41 INFO 140431746283328] Using default worker.
# [11/14/2020 14:28:41 INFO 140431746283328] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [11/14/2020 14:28:41 INFO 140431746283328] Loaded iterator creator application/x-labeled-vector-protobuf for content type ('application/x-labeled-vector-protobuf', '1.0')
# [11/14/2020 14:28:41 INFO 140431746283328] Loaded iterator creator protobuf for content type ('protobuf', '1.0')
# [11/14/2020 14:28:41 INFO 140431746283328] Checkpoint loading and saving are disabled.
# [11/14/2020 14:28:41 INFO 140431746283328] Create Store: dist_sync
# [11/14/2020 14:28:42 INFO 140431746283328] nvidia-smi took: 0.0252740383148 secs to identify 0 gpus
# [11/14/2020 14:28:42 INFO 140431746283328] Number of GPUs being used: 0
# [11/14/2020 14:28:42 INFO 140431746283328] The default executor is <RandomizedPCAExecutor on cpu(0)>.
# [11/14/2020 14:28:42 INFO 140431746283328] 20 feature(s) found in 'data'.
# [11/14/2020 14:28:42 INFO 140431746283328] <RandomizedPCAExecutor on cpu(0)> is assigned to batch slice from 0 to 199.
# [11/14/2020 14:28:42 WARNING 140431746283328] The total number of components and extra components should be less than the number of features.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 743.3741092681885, "sum": 743.3741092681885, "min": 743.3741092681885}}, "EndTime": 1605364122.381087, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605364121.62189}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1605364122.381346, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605364122.381264}
#
# [2020-11-14 14:28:42.381] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 758, "num_examples": 1, "num_bytes": 20800}
# [2020-11-14 14:28:42.417] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 28, "num_examples": 4, "num_bytes": 76960}
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 36.06915473937988, "sum": 36.06915473937988, "min": 36.06915473937988}}, "EndTime": 1605364122.417831, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605364122.381185}
#
# [11/14/2020 14:28:42 INFO 140431746283328] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Total Batches Seen": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Total Records Seen": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Max Records Seen Between Resets": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1605364122.418128, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "PCA", "epoch": 0}, "StartTime": 1605364122.381726}
#
# [11/14/2020 14:28:42 INFO 140431746283328] #throughput_metric: host=algo-1, train throughput=20264.4548327 records/second
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 14.060020446777344, "sum": 14.060020446777344, "min": 14.060020446777344}}, "EndTime": 1605364122.432465, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605364122.417902}
#
# [11/14/2020 14:28:42 INFO 140431746283328] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2475.1150608062744, "sum": 2475.1150608062744, "min": 2475.1150608062744}, "setuptime": {"count": 1, "max": 1547.3060607910156, "sum": 1547.3060607910156, "min": 1547.3060607910156}}, "EndTime": 1605364122.437023, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605364122.432522}
#
#
# 2020-11-14 14:28:49 Uploading - Uploading generated training model
# 2020-11-14 14:28:49 Completed - Training job completed
# Training seconds: 72
# Billable seconds: 72

# %%
# %%time
#pca_SM.fit(pca_SM.record_set(train_data))
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-11-14 13:50:01 Starting - Starting the training job...
# 2020-11-14 13:50:06 Starting - Launching requested ML instances......
# 2020-11-14 13:51:10 Starting - Preparing the instances for training......
# 2020-11-14 13:52:16 Downloading - Downloading input data...
# 2020-11-14 13:52:52 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/14/2020 13:52:55 INFO 139823502825280] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto'}
# [11/14/2020 13:52:55 INFO 139823502825280] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'20', u'mini_batch_size': u'500', u'num_components': u'19'}
# [11/14/2020 13:52:55 INFO 139823502825280] Final configuration: {u'num_components': u'19', u'_num_gpus': u'auto', u'_log_level': u'info', u'subtract_mean': u'true', u'force_dense': u'true', u'epochs': 1, u'algorithm_mode': u'regular', u'feature_dim': u'20', u'extra_components': u'-1', u'_kvstore': u'dist_sync', u'_num_kv_servers': u'auto', u'mini_batch_size': u'500'}
# [11/14/2020 13:52:55 WARNING 139823502825280] Loggers have already been setup.
# [11/14/2020 13:52:57 INFO 139823502825280] Launching parameter server for role scheduler
# [11/14/2020 13:52:57 INFO 139823502825280] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/d2462758-b790-4edf-8437-011aa18facb0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/d2462758-b790-4edf-8437-011aa18facb0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-13-50-01-190', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-172-188.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ad5d41ba-ff8a-4e3c-8a2b-a2600b158ffe', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-13-50-01-190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 13:52:57 INFO 139823502825280] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/d2462758-b790-4edf-8437-011aa18facb0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/d2462758-b790-4edf-8437-011aa18facb0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.172.188', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-13-50-01-190', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-172-188.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ad5d41ba-ff8a-4e3c-8a2b-a2600b158ffe', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-13-50-01-190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 13:52:57 INFO 139823502825280] Launching parameter server for role server
# [11/14/2020 13:52:57 INFO 139823502825280] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/d2462758-b790-4edf-8437-011aa18facb0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/d2462758-b790-4edf-8437-011aa18facb0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-13-50-01-190', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-172-188.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ad5d41ba-ff8a-4e3c-8a2b-a2600b158ffe', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-13-50-01-190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 13:52:57 INFO 139823502825280] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/d2462758-b790-4edf-8437-011aa18facb0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/d2462758-b790-4edf-8437-011aa18facb0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '1', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.172.188', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-13-50-01-190', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-172-188.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ad5d41ba-ff8a-4e3c-8a2b-a2600b158ffe', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-13-50-01-190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [11/14/2020 13:52:57 INFO 139823502825280] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/d2462758-b790-4edf-8437-011aa18facb0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/d2462758-b790-4edf-8437-011aa18facb0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '1', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.172.188', 'AWS_REGION': 'eu-central-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'pca-2020-11-14-13-50-01-190', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '2', 'HOSTNAME': 'ip-10-0-172-188.eu-central-1.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/ad5d41ba-ff8a-4e3c-8a2b-a2600b158ffe', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:eu-central-1:773208840593:training-job/pca-2020-11-14-13-50-01-190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 60 is a shell:scheduler.
# Process 69 is a shell:server.
# Process 1 is a worker.
# [11/14/2020 13:52:57 INFO 139823502825280] Using default worker.
# [11/14/2020 13:52:57 INFO 139823502825280] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [11/14/2020 13:52:57 INFO 139823502825280] Loaded iterator creator application/x-labeled-vector-protobuf for content type ('application/x-labeled-vector-protobuf', '1.0')
# [11/14/2020 13:52:57 INFO 139823502825280] Loaded iterator creator protobuf for content type ('protobuf', '1.0')
# [11/14/2020 13:52:57 INFO 139823502825280] Checkpoint loading and saving are disabled.
# [11/14/2020 13:52:57 INFO 139823502825280] Create Store: dist_sync
# [11/14/2020 13:52:57 INFO 139823502825280] nvidia-smi took: 0.0252239704132 secs to identify 0 gpus
# [11/14/2020 13:52:57 INFO 139823502825280] Number of GPUs being used: 0
# [11/14/2020 13:52:57 INFO 139823502825280] The default executor is <PCAExecutor on cpu(0)>.
# [11/14/2020 13:52:57 INFO 139823502825280] 20 feature(s) found in 'data'.
# [11/14/2020 13:52:57 INFO 139823502825280] <PCAExecutor on cpu(0)> is assigned to batch slice from 0 to 499.
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 595.0407981872559, "sum": 595.0407981872559, "min": 595.0407981872559}}, "EndTime": 1605361977.903826, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605361977.304255}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1605361977.904062, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605361977.904}
#
# [2020-11-14 13:52:57.904] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 599, "num_examples": 1, "num_bytes": 52000}
# [2020-11-14 13:52:57.939] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 27, "num_examples": 2, "num_bytes": 76960}
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "update.time": {"count": 1, "max": 35.279035568237305, "sum": 35.279035568237305, "min": 35.279035568237305}}, "EndTime": 1605361977.939704, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605361977.903929}
#
# [11/14/2020 13:52:57 INFO 139823502825280] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Batches Since Last Reset": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Number of Records Since Last Reset": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Max Records Seen Between Resets": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1605361977.940037, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "PCA", "epoch": 0}, "StartTime": 1605361977.904397}
#
# [11/14/2020 13:52:57 INFO 139823502825280] #throughput_metric: host=algo-1, train throughput=20678.9409304 records/second
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 14.405012130737305, "sum": 14.405012130737305, "min": 14.405012130737305}}, "EndTime": 1605361977.954796, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605361977.939804}
#
# [11/14/2020 13:52:57 INFO 139823502825280] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2810.474157333374, "sum": 2810.474157333374, "min": 2810.474157333374}, "setuptime": {"count": 1, "max": 2036.229133605957, "sum": 2036.229133605957, "min": 2036.229133605957}}, "EndTime": 1605361977.959667, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "PCA"}, "StartTime": 1605361977.954844}
#
#
# 2020-11-14 13:53:08 Uploading - Uploading generated training model
# 2020-11-14 13:53:08 Failed - Training job failed
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/amazon/amazon_estimator.py in fit(self, records, mini_batch_size, wait, logs, job_name, experiment_config)
#     250         )
#     251         if wait:
# --> 252             self.latest_training_job.wait(logs=logs)
#     253
#     254     def record_set(self, train, labels=None, channel="train", encrypt=False):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1137         # If logs are requested, call logs_for_jobs.
#    1138         if logs != "None":
# -> 1139             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1140         else:
#    1141             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3075
#    3076         if wait:
# -> 3077             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3078             if dot:
#    3079                 print()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    2669                 ),
#    2670                 allowed_statuses=["Completed", "Stopped"],
# -> 2671                 actual_status=status,
#    2672             )
#    2673
#
# UnexpectedStatusException: Error for Training job pca-2020-11-14-13-50-01-190: Failed. Reason: ClientError: Artifact upload failed:Error 7: PermanentRedirect (301): The bucket is in this region: us-east-1. Please use this region to retry the request

# %%
# Store model artifacts on S3
job_name = pca.latest_training_job.name
model_key = "absence/" + job_name + "/output/model.tar.gz"
print(model_key)
print(bucket_name)
boto3.resource('s3').Bucket(bucket_name).download_file(model_key, 'model.tar.gz')
os.system('tar -zxvf model.tar.gz')
# Out:
# absence/pca-2020-11-14-14-25-26-361/output/model.tar.gz
# raz-eu-central-1-tutorial
# 0

# %%
pip install mxnet
# Out:
# Collecting mxnet
#   Downloading mxnet-1.7.0.post1-py2.py3-none-manylinux2014_x86_64.whl (55.0 MB)
#      |████████████████████████████████| 55.0 MB 165 kB/s eta 0:00:01
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from mxnet) (1.18.1)
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from mxnet) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2020.6.20)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.7.0.post1
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# After the model is decompressed, we can load the ND array using MXNet
import mxnet as mx
pca_model_params = mx.ndarray.load('model_algo-1')

# %%
# Exact explained-variance-ratio vector
s=pd.DataFrame(pca_model_params['s'].asnumpy())
v=pd.DataFrame(pca_model_params['v'].asnumpy())

# %%
# Calculate the variance explained by the largest n components that we want to keep. 
# Take the top 5 components
# The largest 5 components explain ~62% of the total variance in our dataset
s.iloc[:5,:].apply(lambda x: x*x).sum()/s.apply(lambda x: x*x).sum()
# Out:
# 0    0.677843
# dtype: float32

# %%
# After keeping the top 5 components take only the 5 largest components from original s and v matrix
s_5=s.iloc[:5,:]
v_5=v.iloc[:,:5]
v_5.columns=[0,1,2,3,4]

# %%
v_5.head()
# Out:
#           0         1         2         3         4
# 0 -0.018662  0.168558 -0.311668  0.425759 -0.310506
# 1  0.111394 -0.323697  0.204724  0.080545  0.001571
# 2  0.048350 -0.103454 -0.177061 -0.766576 -0.507569
# 3  0.162550 -0.512680  0.486144  0.156508 -0.287492
# 4  0.003099 -0.411461 -0.187276 -0.020765  0.140838

# %%
# Examine the makeup of one of the PCA components based on the weightings of the original features 
# that are included in the component
# Understand what the key positive and negative attributes are for the component
component_num=1

first_comp = v_5[5-component_num]
comps = pd.DataFrame(list(zip(first_comp, absence_scaled.columns)), columns=['weights', 'features'])
comps['abs_weights']=comps['weights'].apply(lambda x: np.abs(x))
ax=sns.barplot(data=comps.sort_values('abs_weights', ascending=False).head(10), x="weights", y="features", palette="Blues_d")
ax.set_title("PCA Component Makeup: #" + str(component_num))
plt.show()

# %%
# %%time
pca_predictor = pca.deploy(initial_instance_count=1, 
                                 instance_type='ml.t2.medium')
# Deploy the PCA model
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!CPU times: user 280 ms, sys: 11.6 ms, total: 291 ms
# Wall time: 7min 31s

# %%
vectors[0].shape
# Out:
# (20,)

# %%
vectors.shape
result = pca_predictor.predict([vectors])
print(result)
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-49-c1d444999bf9> in <module>
#       1 vectors.shape
# ----> 2 result = pca_predictor.predict([vectors])
#       3 print(result)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant)
#     111
#     112         request_args = self._create_request_args(data, initial_args, target_model, target_variant)
# --> 113         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     114         return self._handle_response(response)
#     115
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     647         }
#     648         request_dict = self._convert_to_request_dict(
# --> 649             api_params, operation_model, context=request_context)
#     650
#     651         service_id = self._service_model.service_id.hyphenize()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     695             api_params, operation_model, context)
#     696         request_dict = self._serializer.serialize_to_request(
# --> 697             api_params, operation_model)
#     698         if not self._client_config.inject_host_prefix:
#     699             request_dict.pop('host_prefix', None)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     295                                                     operation_model.input_shape)
#     296             if report.has_errors():
# --> 297                 raise ParamValidationError(report=report.generate_report())
#     298         return self._serializer.serialize_to_request(parameters,
#     299                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Invalid type for parameter Body, value: [array([[0.9285714 , 0.5833333 , 0.25      , ..., 0.27272728, 0.57894737,
#         0.03333334],
#        [0.        , 0.5833333 , 0.25      , ..., 0.45454547, 0.6315789 ,
#         0.        ],
#        [0.8214286 , 0.5833333 , 0.5       , ..., 0.21212122, 0.6315789 ,
#         0.01666667],
#        ...,
#        [0.        , 0.        , 0.25      , ..., 0.21212122, 0.7894737 ,
#         0.        ],
#        [0.        , 0.        , 0.5       , ..., 0.21212122, 0.84210527,
#         0.        ],
#        [0.        , 0.        , 1.        , ..., 0.36363637, 0.31578946,
#         0.        ]], dtype=float32)], type: <class 'list'>, valid types: <class 'bytes'>, <class 'bytearray'>, file-like object

# %%
# %%time
result = pca_predictor.predict(vectors)
# Pass our original dataset to the model so that we can transform the data using the model we created
# Take the largest 5 components and this will reduce the dimensionality of our data from 19 to 5
# Out:
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant)
#     111
#     112         request_args = self._create_request_args(data, initial_args, target_model, target_variant)
# --> 113         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     114         return self._handle_response(response)
#     115
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     647         }
#     648         request_dict = self._convert_to_request_dict(
# --> 649             api_params, operation_model, context=request_context)
#     650
#     651         service_id = self._service_model.service_id.hyphenize()
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     695             api_params, operation_model, context)
#     696         request_dict = self._serializer.serialize_to_request(
# --> 697             api_params, operation_model)
#     698         if not self._client_config.inject_host_prefix:
#     699             request_dict.pop('host_prefix', None)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     295                                                     operation_model.input_shape)
#     296             if report.has_errors():
# --> 297                 raise ParamValidationError(report=report.generate_report())
#     298         return self._serializer.serialize_to_request(parameters,
#     299                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Invalid type for parameter Body, value: [[0.9285714  0.5833333  0.25       ... 0.27272728 0.57894737 0.03333334]
#  [0.         0.5833333  0.25       ... 0.45454547 0.6315789  0.        ]
#  [0.8214286  0.5833333  0.5        ... 0.21212122 0.6315789  0.01666667]
#  ...
#  [0.         0.         0.25       ... 0.21212122 0.7894737  0.        ]
#  [0.         0.         0.5        ... 0.21212122 0.84210527 0.        ]
#  [0.         0.         1.         ... 0.36363637 0.31578946 0.        ]], type: <class 'numpy.ndarray'>, valid types: <class 'bytes'>, <class 'bytearray'>, file-like object

# %%
# Create a dataset where each absenteeism is described by the 5 principle components
PCA_list=['Social drinker', 'Distance from Residence to Work', 'Weight', 'Education', 'Body mass index']
absence_transformed=pd.DataFrame()
for a in result:
    b=a.label['projection'].float32_tensor.values
    absence_transformed=absence_transformed.append([list(b)])
absence_transformed.index=absence_scaled.index
absence_transformed=absence_transformed.iloc[:,14:]
absence_transformed.columns=PCA_list

# %%
absence_transformed.head()
# Out:
#                     Social drinker  Distance from Residence to Work    Weight  \
# Reason for absence
# 26                        0.220163                         0.277262  0.023891
# 0                        -0.813139                         0.473745 -0.941796
# 23                        0.119235                        -0.130268 -0.052720
# 7                        -0.839607                         0.590692  0.207264
# 23                       -0.115692                         0.061643  0.277216
#
#                     Education  Body mass index
# Reason for absence
# 26                   0.416488        -0.574165
# 0                    0.071819        -0.446411
# 23                   0.539152        -0.643213
# 7                    0.134280        -0.147293
# 23                   0.362107        -0.585175

# %%
# Use the Kmeans algorithm to segment the absenteeism by the 5 PCA attributes we have created.
train_data = absence_transformed.values.astype('float32')

# %%
# Find the top 7 clusters from our dataset
from sagemaker import KMeans

num_clusters = 7
kmeans = KMeans(role=role,
                train_instance_count=1,
                train_instance_type='ml.c4.xlarge',
                output_path='s3://'+ bucket +'/absence/',              
                k=num_clusters)

# %%
# %%time
kmeans.fit(kmeans.record_set(train_data))
# Out:
# 2020-02-18 02:25:53 Starting - Starting the training job...
# 2020-02-18 02:25:55 Starting - Launching requested ML instances......
# 2020-02-18 02:26:59 Starting - Preparing the instances for training...
# 2020-02-18 02:27:43 Downloading - Downloading input data...
# 2020-02-18 02:27:57 Training - Downloading the training image......
# 2020-02-18 02:29:22 Uploading - Uploading generated training model
# 2020-02-18 02:29:22 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# [02/18/2020 02:29:13 INFO 140491501401920] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [02/18/2020 02:29:13 INFO 140491501401920] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'5', u'k': u'7', u'force_dense': u'True'}
# [02/18/2020 02:29:13 INFO 140491501401920] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'5', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'7', u'_num_slices': u'1'}
# [02/18/2020 02:29:13 WARNING 140491501401920] Loggers have already been setup.
# Process 1 is a worker.
# [02/18/2020 02:29:13 INFO 140491501401920] Using default worker.
# [02/18/2020 02:29:13 INFO 140491501401920] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [02/18/2020 02:29:13 INFO 140491501401920] Create Store: local
# [02/18/2020 02:29:13 INFO 140491501401920] nvidia-smi took: 0.0251748561859 secs to identify 0 gpus
# [02/18/2020 02:29:13 INFO 140491501401920] Number of GPUs being used: 0
# [02/18/2020 02:29:13 INFO 140491501401920] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'1', u'feature_dim': u'5', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'7', u'_num_slices': u'1'}
# [02/18/2020 02:29:13 INFO 140491501401920] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [02/18/2020 02:29:13 INFO 140491501401920] Number of GPUs being used: 0
# [02/18/2020 02:29:13 INFO 140491501401920] number of center slices 1
# [02/18/2020 02:29:13 WARNING 140491501401920] Batch size 5000 is bigger than the first batch data. Effective batch size used to initialize is 740
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Max Records Seen Between Resets": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1581992953.656437, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1581992953.656406}
#
# [2020-02-18 02:29:13.656] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 30, "num_examples": 1, "num_bytes": 32560}
# [2020-02-18 02:29:13.699] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 42, "num_examples": 1, "num_bytes": 32560}
# [02/18/2020 02:29:13 INFO 140491501401920] processed a total of 740 examples
# [02/18/2020 02:29:13 INFO 140491501401920] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 1480, "sum": 1480.0, "min": 1480}, "Max Records Seen Between Resets": {"count": 1, "max": 740, "sum": 740.0, "min": 740}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1581992953.700207, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1581992953.656665}
#
# [02/18/2020 02:29:13 INFO 140491501401920] #throughput_metric: host=algo-1, train throughput=16946.7753578 records/second
# [02/18/2020 02:29:13 WARNING 140491501401920] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/18/2020 02:29:13 INFO 140491501401920] shrinking 70 centers into 7
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #0. Current mean square distance 0.267164
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #1. Current mean square distance 0.255519
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #2. Current mean square distance 0.268737
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #3. Current mean square distance 0.254238
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #4. Current mean square distance 0.272609
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #5. Current mean square distance 0.278503
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #6. Current mean square distance 0.268334
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #7. Current mean square distance 0.242600
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #8. Current mean square distance 0.272297
# [02/18/2020 02:29:13 INFO 140491501401920] local kmeans attempt #9. Current mean square distance 0.269440
# [02/18/2020 02:29:13 INFO 140491501401920] finished shrinking process. Mean Square Distance = 0
# [02/18/2020 02:29:13 INFO 140491501401920] #quality_metric: host=algo-1, train msd <loss>=0.242599859834
# [02/18/2020 02:29:13 INFO 140491501401920] compute all data-center distances: inner product took: 34.1606%, (0.016924 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] collect from kv store took: 13.9294%, (0.006901 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] splitting centers key-value pair took: 13.7335%, (0.006804 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] gradient: one_hot took: 10.3346%, (0.005120 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] gradient: cluster center took: 9.6137%, (0.004763 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] compute all data-center distances: point norm took: 8.0415%, (0.003984 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] predict compute msd took: 4.1319%, (0.002047 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] batch data loading with context took: 3.4538%, (0.001711 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] update state and report convergance took: 1.0212%, (0.000506 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] gradient: cluster size  took: 0.8253%, (0.000409 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] update set-up time took: 0.4158%, (0.000206 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] compute all data-center distances: center norm took: 0.2964%, (0.000147 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] predict minus dist took: 0.0423%, (0.000021 secs)
# [02/18/2020 02:29:13 INFO 140491501401920] TOTAL took: 0.0495429039001
# [02/18/2020 02:29:13 INFO 140491501401920] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 276.57604217529297, "sum": 276.57604217529297, "min": 276.57604217529297}, "initialize.time": {"count": 1, "max": 28.434038162231445, "sum": 28.434038162231445, "min": 28.434038162231445}, "model.serialize.time": {"count": 1, "max": 0.16188621520996094, "sum": 0.16188621520996094, "min": 0.16188621520996094}, "update.time": {"count": 1, "max": 43.35594177246094, "sum": 43.35594177246094, "min": 43.35594177246094}, "epochs": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "state.serialize.time": {"count": 1, "max": 1.177072525024414, "sum": 1.177072525024414, "min": 1.177072525024414}, "_shrink.time": {"count": 1, "max": 274.72710609436035, "sum": 274.72710609436035, "min": 274.72710609436035}}, "EndTime": 1581992953.9786, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1581992953.625163}
#
# [02/18/2020 02:29:13 INFO 140491501401920] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 419.1310405731201, "sum": 419.1310405731201, "min": 419.1310405731201}, "setuptime": {"count": 1, "max": 13.462066650390625, "sum": 13.462066650390625, "min": 13.462066650390625}}, "EndTime": 1581992953.978951, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1581992953.978695}
#
# Training seconds: 99
# Billable seconds: 99
# CPU times: user 552 ms, sys: 33.4 ms, total: 586 ms
# Wall time: 3min 42s

# %%
# %%time
kmeans_predictor = kmeans.deploy(initial_instance_count=1, 
                                 instance_type='ml.t2.medium')
# Deploy the model
# Out:
# -----------------------!CPU times: user 358 ms, sys: 30 ms, total: 388 ms
# Wall time: 11min 32s

# %%
# %%time
result=kmeans_predictor.predict(train_data)
# Out:
# CPU times: user 51.9 ms, sys: 4.45 ms, total: 56.3 ms
# Wall time: 324 ms

# %%
# Breakdown of cluster counts and the distribution of clusters
cluster_labels = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]

# %%
pd.DataFrame(cluster_labels)[0].value_counts()
# Out:
# 2.0    138
# 0.0    114
# 1.0    111
# 4.0    110
# 3.0     96
# 5.0     89
# 6.0     82
# Name: 0, dtype: int64

# %%
ax=plt.subplots(figsize=(6,3))
ax=sns.distplot(cluster_labels, kde=False)
title="Histogram of Cluster Counts"
ax.set_title(title, fontsize=12)
plt.show()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# Access the underlying model to get the cluster centers
# Centers will help describe which features characterize each cluster
# First retrieve the K-Means model attributes
job_name = kmeans.latest_training_job.name
model_key = "absence/" + job_name + "/output/model.tar.gz"

boto3.resource('s3').Bucket(bucket).download_file(model_key, 'model.tar.gz')
os.system('tar -zxvf model.tar.gz')
# Out:
# 0

# %%
Kmeans_model_params = mx.ndarray.load('model_algo-1')

# %%
# Cluster Centroid Locations: The location of the centers of each cluster identified by the Kmeans algorithm
cluster_centroids=pd.DataFrame(Kmeans_model_params[0].asnumpy())
cluster_centroids.columns=absence_transformed.columns

# %%
cluster_centroids
# Out:
#    Social drinker  Distance from Residence to Work    Weight  Education  \
# 0       -0.194499                        -0.061751  0.357695   0.185599
# 1        0.072919                         0.208198 -0.263245   0.256122
# 2        0.170031                         0.178539 -0.110450   0.290928
# 3        0.117853                        -0.079949 -0.034841  -0.466216
# 4       -0.145866                        -0.142386  0.292171   0.223818
# 5        0.222085                        -0.052123  0.152401  -0.581722
# 6       -0.341128                        -0.128244 -0.547628  -0.137222
#
#    Body mass index
# 0        -0.471168
# 1         0.633057
# 2        -0.498988
# 3         0.614537
# 4         0.644043
# 5        -0.477426
# 6        -0.414144

# %%
# Plot a heatmap of the centroids and their location in the transformed feature space
plt.figure(figsize = (16, 6))
ax = sns.heatmap(cluster_centroids.T, cmap = 'YlGnBu')
ax.set_xlabel("Cluster")
plt.yticks(fontsize = 16)
plt.xticks(fontsize = 16)
ax.set_title("Attribute Value by Centroid")
plt.show()

# %%
# Map the cluster labels back to each individual absenteeism and examine which were naturally grouped together
absence_transformed['labels']=list(map(int, cluster_labels))
absence_transformed.head()
# Out:
#                     Social drinker  Distance from Residence to Work    Weight  \
# Reason for absence
# 26                        0.220163                         0.277262  0.023891
# 0                        -0.813139                         0.473745 -0.941796
# 23                        0.119235                        -0.130268 -0.052720
# 7                        -0.839607                         0.590692  0.207264
# 23                       -0.115692                         0.061643  0.277216
#
#                     Education  Body mass index  labels
# Reason for absence
# 26                   0.416488        -0.574165       2
# 0                    0.071819        -0.446411       6
# 23                   0.539152        -0.643213       2
# 7                    0.134280        -0.147293       0
# 23                   0.362107        -0.585175       0

# %%
# Examine one of the clusters in more detail
cluster=absence_transformed[absence_transformed['labels']==1]
cluster.head(5)
# Out:
#                     Social drinker  Distance from Residence to Work    Weight  \
# Reason for absence
# 22                        0.168640                         0.200160 -0.450106
# 23                       -0.030780                        -0.020388 -0.108434
# 10                       -0.050468                         0.298167 -0.049213
# 18                        0.045163                         0.521368 -0.352631
# 23                        0.520496                         0.189885  0.255469
#
#                     Education  Body mass index  labels
# Reason for absence
# 22                   0.484331         0.634288       1
# 23                   0.353993         0.284006       1
# 10                   0.243537         0.644102       1
# 18                   0.338169         0.385478       1
# 23                   0.403811         0.571548       1

# %%
# Delete the PCA endpoint
sagemaker.Session().delete_endpoint(pca_predictor.endpoint)

# %%
# Delete the K-Means endpoint
sagemaker.Session().delete_endpoint(kmeans_predictor.endpoint)
